# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/daum0/Downloads/카카오톡 받은 파일/주차난 프로젝트/중구 주차난 분석/car_all.csv")

# %%
df
# Out:
#              민원접수일    민원접수시간          경도         위도             _PARCEL_AD  \
# 0       20231001.0   0:00:00  126.981032  37.554950   서울특별시 중구 회현동1가 산 1-2
# 1       20231001.0   0:00:00  126.981032  37.554950   서울특별시 중구 회현동1가 산 1-2
# 2       20231001.0   0:00:00  126.981032  37.554950   서울특별시 중구 회현동1가 산 1-2
# 3       20231001.0   0:00:00  126.981032  37.554950   서울특별시 중구 회현동1가 산 1-2
# 4       20231001.0   0:00:00  126.981032  37.554950   서울특별시 중구 회현동1가 산 1-2
# ...            ...       ...         ...        ...                    ...
# 134529  20231031.0  23:55:00  127.009894  37.535221     서울특별시 용산구 한남동 31-5
# 134530  20231031.0  23:56:00  126.865180  37.534377     서울특별시 양천구 목동 786-6
# 134531  20231031.0  23:59:00  127.001042  37.506165     서울특별시 서초구 잠원동 76-5
# 134532  20231031.0  23:59:00  127.005346  37.511840     서울특별시 서초구 잠원동 71-8
# 134533  20231031.0  23:59:00  126.991668  37.541993  서울특별시 용산구 이태원동 260-54
#
#        _PARCEL_DT                 _ROAD_AD _ROAD_DT
# 0            0.0m    서울특별시 중구 회현동1가 소파로 46    31.0m
# 1            0.0m    서울특별시 중구 회현동1가 소파로 46    31.0m
# 2            0.0m    서울특별시 중구 회현동1가 소파로 46    31.0m
# 3            0.0m    서울특별시 중구 회현동1가 소파로 46    31.0m
# 4            0.0m    서울특별시 중구 회현동1가 소파로 46    31.0m
# ...           ...                      ...      ...
# 134529       0.0m  서울특별시 용산구 한남대로20길 47-10     0.0m
# 134530       0.0m   서울특별시 양천구 목동중앙서로7나길 11     0.0m
# 134531       0.0m       서울특별시 서초구 반포대로 304     0.0m
# 134532       0.0m     서울특별시 서초구 신반포로23길 76     0.0m
# 134533       0.0m      서울특별시 용산구 소월로40길 49     0.0m
#
# [134534 rows x 8 columns]

# %%
# 주소 나누기
df[['시', '구', '도로1', '도로2','건물번호']] = df['_ROAD_AD'].str.split(' ', expand=True)
df.head()
# Out:
#         민원접수일   민원접수시간          경도        위도            _PARCEL_AD _PARCEL_DT  \
# 0  20231001.0  0:00:00  126.981032  37.55495  서울특별시 중구 회현동1가 산 1-2       0.0m
# 1  20231001.0  0:00:00  126.981032  37.55495  서울특별시 중구 회현동1가 산 1-2       0.0m
# 2  20231001.0  0:00:00  126.981032  37.55495  서울특별시 중구 회현동1가 산 1-2       0.0m
# 3  20231001.0  0:00:00  126.981032  37.55495  서울특별시 중구 회현동1가 산 1-2       0.0m
# 4  20231001.0  0:00:00  126.981032  37.55495  서울특별시 중구 회현동1가 산 1-2       0.0m
#
#                 _ROAD_AD _ROAD_DT      시   구    도로1  도로2 건물번호
# 0  서울특별시 중구 회현동1가 소파로 46    31.0m  서울특별시  중구  회현동1가  소파로   46
# 1  서울특별시 중구 회현동1가 소파로 46    31.0m  서울특별시  중구  회현동1가  소파로   46
# 2  서울특별시 중구 회현동1가 소파로 46    31.0m  서울특별시  중구  회현동1가  소파로   46
# 3  서울특별시 중구 회현동1가 소파로 46    31.0m  서울특별시  중구  회현동1가  소파로   46
# 4  서울특별시 중구 회현동1가 소파로 46    31.0m  서울특별시  중구  회현동1가  소파로   46

# %%
# 컬럼 지우기
df = df.drop(columns=['경도', '위도','_PARCEL_AD','_PARCEL_DT','_ROAD_AD', '_ROAD_DT', '시', '도로1', '도로2', '건물번호'])
df.head()
# Out:
#         민원접수일   민원접수시간   구
# 0  20231001.0  0:00:00  중구
# 1  20231001.0  0:00:00  중구
# 2  20231001.0  0:00:00  중구
# 3  20231001.0  0:00:00  중구
# 4  20231001.0  0:00:00  중구

# %%
# 평일== 0 /주말 == 1
df['요일'] = pd.to_datetime(df['민원접수일'], format='%Y%m%d').dt.dayofweek
df['평일/주말'] = df['요일'].apply(lambda x: 0 if x < 5 else 1)
df
# Out:
#              민원접수일    민원접수시간    구  요일  평일/주말
# 0       20231001.0   0:00:00   중구   6      1
# 1       20231001.0   0:00:00   중구   6      1
# 2       20231001.0   0:00:00   중구   6      1
# 3       20231001.0   0:00:00   중구   6      1
# 4       20231001.0   0:00:00   중구   6      1
# ...            ...       ...  ...  ..    ...
# 134529  20231031.0  23:55:00  용산구   1      0
# 134530  20231031.0  23:56:00  양천구   1      0
# 134531  20231031.0  23:59:00  서초구   1      0
# 134532  20231031.0  23:59:00  서초구   1      0
# 134533  20231031.0  23:59:00  용산구   1      0
#
# [134534 rows x 5 columns]

# %%
df_junggu = df[df['구'] == '중구']
df_junggu
# Out:
#              민원접수일    민원접수시간   구  요일  평일/주말
# 0       20231001.0   0:00:00  중구   6      1
# 1       20231001.0   0:00:00  중구   6      1
# 2       20231001.0   0:00:00  중구   6      1
# 3       20231001.0   0:00:00  중구   6      1
# 4       20231001.0   0:00:00  중구   6      1
# ...            ...       ...  ..  ..    ...
# 134414  20231031.0  23:03:00  중구   1      0
# 134454  20231031.0  23:19:00  중구   1      0
# 134462  20231031.0  23:20:00  중구   1      0
# 134517  20231031.0  23:44:00  중구   1      0
# 134520  20231031.0  23:47:00  중구   1      0
#
# [16424 rows x 5 columns]

# %%
def adjust_to_20_minutes(time):
    parts = time.split(':')
    hour = parts[0].zfill(2)
    minute = parts[1]
    second = parts[2]
    minute_adjusted = str(int(minute) // 20 * 20).zfill(2)  # 20분 간격으로 조정
    return f"{hour}:{minute_adjusted}:{second}"

# 시간 열을 20분 간격으로 조정하여 새로운 컬럼에 할당
df['시간'] = df['민원접수시간'].apply(adjust_to_20_minutes)

df
# Out:
#              민원접수일    민원접수시간    구  요일  평일/주말        시간
# 0       20231001.0   0:00:00   중구   6      1  00:00:00
# 1       20231001.0   0:00:00   중구   6      1  00:00:00
# 2       20231001.0   0:00:00   중구   6      1  00:00:00
# 3       20231001.0   0:00:00   중구   6      1  00:00:00
# 4       20231001.0   0:00:00   중구   6      1  00:00:00
# ...            ...       ...  ...  ..    ...       ...
# 134529  20231031.0  23:55:00  용산구   1      0  23:40:00
# 134530  20231031.0  23:56:00  양천구   1      0  23:40:00
# 134531  20231031.0  23:59:00  서초구   1      0  23:40:00
# 134532  20231031.0  23:59:00  서초구   1      0  23:40:00
# 134533  20231031.0  23:59:00  용산구   1      0  23:40:00
#
# [134534 rows x 6 columns]

# %%
df['민원접수일'] = df['민원접수일'].astype(int).astype(str)

df['민원접수일'] = pd.to_datetime(df['민원접수일'], format='%Y%m%d')
df
# Out:
#             민원접수일    민원접수시간    구  요일  평일/주말        시간
# 0      2023-10-01   0:00:00   중구   6      1  00:00:00
# 1      2023-10-01   0:00:00   중구   6      1  00:00:00
# 2      2023-10-01   0:00:00   중구   6      1  00:00:00
# 3      2023-10-01   0:00:00   중구   6      1  00:00:00
# 4      2023-10-01   0:00:00   중구   6      1  00:00:00
# ...           ...       ...  ...  ..    ...       ...
# 134529 2023-10-31  23:55:00  용산구   1      0  23:40:00
# 134530 2023-10-31  23:56:00  양천구   1      0  23:40:00
# 134531 2023-10-31  23:59:00  서초구   1      0  23:40:00
# 134532 2023-10-31  23:59:00  서초구   1      0  23:40:00
# 134533 2023-10-31  23:59:00  용산구   1      0  23:40:00
#
# [134534 rows x 6 columns]

# %%
holidays = ['20231002', '20231003', '20231009']

for holiday in holidays:
    df.loc[df['민원접수일'] == holiday, '평일/주말'] = 1

# %%
df
# Out:
#             민원접수일    민원접수시간    구  요일  평일/주말        시간
# 0      2023-10-01   0:00:00   중구   6      1  00:00:00
# 1      2023-10-01   0:00:00   중구   6      1  00:00:00
# 2      2023-10-01   0:00:00   중구   6      1  00:00:00
# 3      2023-10-01   0:00:00   중구   6      1  00:00:00
# 4      2023-10-01   0:00:00   중구   6      1  00:00:00
# ...           ...       ...  ...  ..    ...       ...
# 134529 2023-10-31  23:55:00  용산구   1      0  23:40:00
# 134530 2023-10-31  23:56:00  양천구   1      0  23:40:00
# 134531 2023-10-31  23:59:00  서초구   1      0  23:40:00
# 134532 2023-10-31  23:59:00  서초구   1      0  23:40:00
# 134533 2023-10-31  23:59:00  용산구   1      0  23:40:00
#
# [134534 rows x 6 columns]

# %%
# 평일== 0 /주말 == 1
df_week = df[(df['평일/주말'] == 0)]
df_hol = df[(df['평일/주말'] == 1)]

# %%
df_hol_group = df_hol.groupby('시간')['민원접수시간'].size().reset_index(name='건수')
df_week_group = df_week.groupby('시간')['민원접수시간'].size().reset_index(name='건수')
df_junggu_all = df.groupby('시간')['민원접수시간'].size().reset_index(name='건수')

# %%
df_hol_group
# Out:
#           시간    건수
# 0   00:00:00   770
# 1   00:20:00   679
# 2   00:40:00   518
# 3   01:00:00   538
# 4   01:20:00   475
# ..       ...   ...
# 67  22:20:00   728
# 68  22:40:00   694
# 69  23:00:00   653
# 70  23:20:00   833
# 71  23:40:00  1017
#
# [72 rows x 2 columns]

# %%
df_week_group
# Out:
#           시간   건수
# 0   00:00:00  635
# 1   00:20:00  540
# 2   00:40:00  479
# 3   01:00:00  417
# 4   01:20:00  195
# ..       ...  ...
# 67  22:20:00  924
# 68  22:40:00  865
# 69  23:00:00  796
# 70  23:20:00  658
# 71  23:40:00  685
#
# [72 rows x 2 columns]

# %%
df_junggu_all
# Out:
#           시간    건수
# 0   00:00:00  1405
# 1   00:20:00  1219
# 2   00:40:00   997
# 3   01:00:00   955
# 4   01:20:00   670
# ..       ...   ...
# 67  22:20:00  1652
# 68  22:40:00  1559
# 69  23:00:00  1449
# 70  23:20:00  1491
# 71  23:40:00  1702
#
# [72 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# 한글 깨짐
plt.rcParams['font.family'] = 'Gulim'

# %%
# 주말 시간대

plt.figure(figsize=(18, 10))
bars = plt.bar(df_hol_group['시간'], df_hol_group['건수'], color='skyblue', width= 0.3)
plt.xlabel('시간')
plt.ylabel('건수')
plt.title('중구 주말 시간대별 민원접수 건수')
plt.xticks(rotation=90)
plt.tight_layout()

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2),ha='center', va='bottom')

plt.show()

# %%
# 평일 시간대

plt.figure(figsize=(18, 10))
bars = plt.bar(df_week_group['시간'], df_week_group['건수'], color='skyblue', width= 0.3)
plt.xlabel('시간')
plt.ylabel('건수')
plt.title('중구 평일 시간대별 민원접수 건수')
plt.xticks(rotation=90)
plt.tight_layout()

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2),ha='center', va='bottom')

plt.show()

# %% [markdown]
# # 2번

# %%
live = pd.read_csv("C:/Users/daum0/Downloads/카카오톡 받은 파일/주차난 프로젝트/중구 주차난 분석/merged_data.csv")
live.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15624 entries, 0 to 15623
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   주차장명       15624 non-null  object
#  1   주소         15624 non-null  object
#  2   총 주차면      15624 non-null  int64
#  3   현재 주차 차량수  15624 non-null  int64
#  4   날짜         15624 non-null  object
#  5   시간         15624 non-null  object
#  6   요일         15624 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 854.6+ KB

# %%
# 주말 여부를 나타내는 새로운 열 추가 
live['평일/주말'] = live['요일'].apply(lambda x: '0' if x in ['월요일', '화요일', '수요일', '목요일', '금요일'] else '1')
live
# Out:
#                           주차장명                 주소  총 주차면  현재 주차 차량수  \
# 0      DDP동측(양쪽) 관광버스전용 주차장(시)      중구 을지로7가 2-36     20         12
# 1      DDP북측 마장로 관광버스전용 주차장(시)       중구 신당동 222-3      4          2
# 2         남대문 시장 관광버스전용 주차장(시)        중구 남창동 51-4      2          3
# 3         남대문 초입 관광버스전용 주차장(시)      중구 남창동 282-10      3          3
# 4              남대문 화물 공영주차장(시)     중구 남대문로4가 24-1      9          3
# ...                        ...                ...    ...        ...
# 15619            청계5가 공영주차장(시)  중구 을지로6가 17-442 0     20         30
# 15620        청계6(동평화) 공영주차장(시)    중구 신당동 217-91 0      6          6
# 15621     청계6(신평화시장앞) 공영주차장(시)    중구 신당동 217-91 0      7          8
# 15622        청계6(청평화) 공영주차장(시)    중구 신당동 217-91 0      5          4
# 15623           훈련원공원 공영주차장(시)      중구 을지로5가 40-3    873        280
#
#               날짜     시간   요일 평일/주말
# 0      2024-2-13    0:0  화요일     0
# 1      2024-2-13    0:0  화요일     0
# 2      2024-2-13    0:0  화요일     0
# 3      2024-2-13    0:0  화요일     0
# 4      2024-2-13    0:0  화요일     0
# ...          ...    ...  ...   ...
# 15619  2024-2-19  23:40  월요일     0
# 15620  2024-2-19  23:40  월요일     0
# 15621  2024-2-19  23:40  월요일     0
# 15622  2024-2-19  23:40  월요일     0
# 15623  2024-2-19  23:40  월요일     0
#
# [15624 rows x 8 columns]

# %%
# 컬럼지우기
live = live.drop(columns= ['주차장명', '주소','총 주차면','날짜','요일'])
live.head()
# Out:
#    현재 주차 차량수   시간 평일/주말
# 0         12  0:0     0
# 1          2  0:0     0
# 2          3  0:0     0
# 3          3  0:0     0
# 4          3  0:0     0

# %%
def convert_to_hh_mm(time):
    hour, minute = time.split(':')
    return '{:02d}:{:02s}'.format(int(hour), minute)

def add_seconds(time):
    return time + ':00'

# 시간 열을 변환하고 :00 추가하여 새로운 컬럼에 할당
live['시간'] = live['시간'].apply(convert_to_hh_mm)
live['시간'] = live['시간'].apply(add_seconds)
live
# Out:
#        현재 주차 차량수        시간 평일/주말
# 0             12  00:00:00     0
# 1              2  00:00:00     0
# 2              3  00:00:00     0
# 3              3  00:00:00     0
# 4              3  00:00:00     0
# ...          ...       ...   ...
# 15619         30  23:40:00     0
# 15620          6  23:40:00     0
# 15621          8  23:40:00     0
# 15622          4  23:40:00     0
# 15623        280  23:40:00     0
#
# [15624 rows x 3 columns]

# %%
live.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15624 entries, 0 to 15623
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   현재 주차 차량수  15624 non-null  int64
#  1   시간         15624 non-null  object
#  2   평일/주말      15624 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 366.3+ KB

# %%
# 평일== 0 /주말 == 1
live_week = live[(live['평일/주말'] == "0")]
live_hol = live[(live['평일/주말'] == "1")]

# %%
live_hol_group = live_hol.groupby('시간')['현재 주차 차량수'].sum().reset_index(name='주차수')
live_week_group = live_week.groupby('시간')['현재 주차 차량수'].sum().reset_index(name='주차수')
live_junggu_all = live.groupby('시간')['현재 주차 차량수'].sum().reset_index(name='주차수')

# %%
live_hol_group
# Out:
#           시간   주차수
# 0   00:00:00  1218
# 1   00:20:00  1295
# 2   00:40:00  1254
# 3   01:00:00  1194
# 4   01:20:00  1228
# ..       ...   ...
# 67  22:20:00  1958
# 68  22:40:00  2023
# 69  23:00:00  2034
# 70  23:20:00  2014
# 71  23:40:00  2032
#
# [72 rows x 2 columns]

# %%
live_week_group
# Out:
#           시간   주차수
# 0   00:00:00  6511
# 1   00:20:00  6484
# 2   00:40:00  6440
# 3   01:00:00  6105
# 4   01:20:00  6172
# ..       ...   ...
# 67  22:20:00  6636
# 68  22:40:00  6707
# 69  23:00:00  6764
# 70  23:20:00  6825
# 71  23:40:00  6899
#
# [72 rows x 2 columns]

# %%
live_junggu_all
# Out:
#           시간   주차수
# 0   00:00:00  7729
# 1   00:20:00  7779
# 2   00:40:00  7694
# 3   01:00:00  7299
# 4   01:20:00  7400
# ..       ...   ...
# 67  22:20:00  8594
# 68  22:40:00  8730
# 69  23:00:00  8798
# 70  23:20:00  8839
# 71  23:40:00  8931
#
# [72 rows x 2 columns]

# %%
# 신고 건수
df_hol_group 
df_week_group 
df_junggu_all


# 라이브
live_hol_group
live_week_group
live_junggu_all

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# 불법신고 주말 건수 정규화

scaler = MinMaxScaler()
columns_to_normalize = ['건수']

# Min-Max 스케일링 적용
df_hol_group[columns_to_normalize] = scaler.fit_transform(df_hol_group[columns_to_normalize])

df_hol_group
# Out:
#           시간        건수
# 0   00:00:00  0.396237
# 1   00:20:00  0.345877
# 2   00:40:00  0.256779
# 3   01:00:00  0.267847
# 4   01:20:00  0.232983
# ..       ...       ...
# 67  22:20:00  0.372994
# 68  22:40:00  0.354178
# 69  23:00:00  0.331489
# 70  23:20:00  0.431101
# 71  23:40:00  0.532928
#
# [72 rows x 2 columns]

# %%
# 주차장데이터 주말 건수 정규화

scaler = MinMaxScaler()
columns_to_normalize = ['주차수']

# Min-Max 스케일링 적용
live_hol_group[columns_to_normalize] = scaler.fit_transform(live_hol_group[columns_to_normalize])

live_hol_group
# Out:
#           시간       주차수
# 0   00:00:00  0.103297
# 1   00:20:00  0.187912
# 2   00:40:00  0.142857
# 3   01:00:00  0.076923
# 4   01:20:00  0.114286
# ..       ...       ...
# 67  22:20:00  0.916484
# 68  22:40:00  0.987912
# 69  23:00:00  1.000000
# 70  23:20:00  0.978022
# 71  23:40:00  0.997802
#
# [72 rows x 2 columns]

# %%
merged_df_hol = pd.merge(live_hol_group, df_hol_group, on='시간', how='inner')
merged_df_hol
# Out:
#           시간       주차수        건수
# 0   00:00:00  0.103297  0.396237
# 1   00:20:00  0.187912  0.345877
# 2   00:40:00  0.142857  0.256779
# 3   01:00:00  0.076923  0.267847
# 4   01:20:00  0.114286  0.232983
# ..       ...       ...       ...
# 67  22:20:00  0.916484  0.372994
# 68  22:40:00  0.987912  0.354178
# 69  23:00:00  1.000000  0.331489
# 70  23:20:00  0.978022  0.431101
# 71  23:40:00  0.997802  0.532928
#
# [72 rows x 3 columns]

# %%
merged_df_hol.corr()
# Out:
#           주차수        건수
# 주차수  1.000000  0.570251
# 건수   0.570251  1.000000
